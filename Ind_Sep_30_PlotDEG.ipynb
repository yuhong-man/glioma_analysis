# %%
# %%bash
# for threshold_for_each in 20 50
# do
#     ExtractRowsWithEachElement_condition_.py 01.inputdata.norm.txt ">${threshold_for_each}"  01.inputdata.norm.eachgt${threshold_for_each}.txt
#     PlotHeatmapByDEGListTopNGenes.py 01.inputdata.norm.eachgt${threshold_for_each}.txt independent_DESeq2_DEG.list 01.coldata.sort.txt 100
# done
# Out:
# ####################Help:
# if __name__ == "__main__":
# import ShowHelp
# path_df_in = sys.argv[1]
# condition_str = sys.argv[2]
# path_output = sys.argv[3]
# df_out = extractRowsWithEveryValue_(path_df_in, condition_str)
# df_out.to_csv(path_output, sep='\t')
# ####################HelpEnd
# [1] "Usage: PlotHeatmapBypheatmap.R path_data fontsize "
# [1] "Drawing using: "
# [1] "01.inputdata.norm.eachgt20.txt.topDEG100.xls"
#         SRR11862856 SRR11862854 SRR11862852 SRR11862850 SRR11862848 SRR11862846
# OSBPL1A   186.38374    96.46602    75.46745    77.15198    91.32833    120.3388
# AKT3      284.27344    61.08110   131.18046   311.15841   242.09806    119.6570
# KIF5A     419.41804    59.39611    85.75433    52.92243    61.17439    140.2134
# PRKACB     47.19682    46.33739    61.63024    86.07866    69.14612     97.3960
# TMED9      56.81099    83.40730   148.65905    91.17962   109.17808    109.0549
# ...

# %%
import pandas as pd 
df_in = pd.read_csv('01.inputdata.txt',sep='\t',index_col=0)
df_in.columns
# Out:
# Index(['SRR11862834', 'SRR11862835', 'SRR11862836', 'SRR11862837',
#        'SRR11862838', 'SRR11862839', 'SRR11862840', 'SRR11862841',
#        'SRR11862842', 'SRR11862843', 'SRR11862844', 'SRR11862845',
#        'SRR11862846', 'SRR11862847', 'SRR11862848', 'SRR11862849',
#        'SRR11862850', 'SRR11862851', 'SRR11862852', 'SRR11862853',
#        'SRR11862854', 'SRR11862855', 'SRR11862856', 'SRR11862857'],
#       dtype='object')

# %%
(df_in['SRR11862857']>1).sum()
# Out:
# 13419
